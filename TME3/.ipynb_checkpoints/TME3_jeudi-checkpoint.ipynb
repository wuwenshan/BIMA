# %% [markdown]
# * <font color='blue'> Dorian QUABOUL 3872944 </font>
# * <font color='blue'> Wenshan WU 3874034 </font>

# %% [markdown]
# # TME3: 2D sampling and aliasing
#
# Properties studied in 1D apply in 2D. The following results can be admitted :
#  - given a regular grid, a sampling of a continuous 2D signal can be modelled as follow:
# $$
# x_e(t,u) = x(t,u)e(t,u)\quad \text{with}\quad e(t,u) = \sum_{k=-\infty}^{+\infty} \sum_{l=-\infty}^{+\infty} \delta(t-kT_e,u - lT_e)
# $$ $e$ is the analog of Dirac comb in 2D
#  - spectrum of $x_e$ writes:
# $$
# X_e(f,g) = \frac1{T_e^2}\sum_{k=-\infty}^{+\infty} \sum_{l=-\infty}^{+\infty} X(f-kf_e,g-lf_e)
# $$
# 2D sampling then implies a periodisation of the spectrum for the two dimensions
#  - it is possible to reconstruct the original signal from the sampled signal if 2D Shannon condition is verified (band limited signal) with:
# $$
# x_r (t,u) = \sum_{k=-\infty}^{+\infty} \sum_{l=\infty}^{+\infty} x_e(kT_e,lT_e) \operatorname{sinc}(\pi f_e (t-kT_e)) \operatorname{sinc}(\pi f_e(u - lTe))\qquad\qquad\qquad\text{(1)}
# $$
# so called Shannon interpolation.
#
# ## Exercice 1: aliasing and windowing of 2D signals
#
# Given the following signal:
# $$
# s_\theta(t,u) = A\cos(2\pi f_0(t\cos\theta + u\sin\theta))
# $$
# Here an example with $\theta=\frac\pi4$:
# <div><img src="attachment:sinus2d.png" width=200></div>
# The goal of this exercice is to study the limit conditions of sampling of this image in order to avoid aliasing.

# %%
import numpy as np
from numpy.fft import fft2, fftshift
import matplotlib.pyplot as plt
# for interactive ploting, see surf() below
# %matplotlib notebook 
from matplotlib import cm
from matplotlib.colors import Normalize
from mpl_toolkits.mplot3d import Axes3D

def sinusoid2d(A, theta, size, T0, Te):
    """ double**2*int*double**2 -> Array[double] """
    ct = np.cos(theta/180*np.pi)
    st = np.sin(theta/180*np.pi)
    x, y = np.meshgrid(np.arange(0, size, Te), np.arange(0, size, Te))
    return A*np.cos(2*np.pi*(y*ct - x*st)/T0)

def shannonInterpolation(I, Te, size):
    """ Array*int*double -> Array[double] """
    n, m = I.shape
    x, y = np.meshgrid(np.arange(0, size), np.arange(0, n))
    Y = np.sinc(x/Te-y)
    x, y = np.meshgrid(np.arange(0, size), np.arange(0, m))
    X = np.sinc(x/Te-y)
    return np.matmul(X.T, np.matmul(I, Y))

def imshow(I,title=None):
    """ display an image """
    plt.figure(figsize=(500//80,500//80))
    plt.gray()
    plt.imshow(I)
    if title: plt.title(title)
    plt.show()

def surf(Z,title=None):
    """ 3D plot of an image """
    X,Y = np.meshgrid(range(Z.shape[1]), range(Z.shape[0]))
    plt.figure(figsize=(600/80,600/80))
    if title: plt.title(title)
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)
    plt.show()

# %% [markdown]
# 1. We provide the function `sinusoid2d(A, theta, L, T0, Te)` that allows to sample signal $s_\theta$ with a sampling period of `Te` (the grid is regular with the sample sampling value for directions $u$ and $t$). Paremeters `A`, `theta`, `L` and `T0` respectively control the amplitude, orientation and period ($T_0=\frac1{f_0}$) of signal $s_\theta$. Generate a pseudo continuous signal $s_{45}$ with `A=1`, `theta = 45`, `L = 512`, `T0 = 64` and `T_e=1`.

# %%
s1 = sinusoid2d(1, 45, 512, 64, 1)
imshow(s1)

# %% [markdown]
# 2. What is the maximal frequency of previous signal $s_{45}$ in direction $t$ (denoted $f_t^{\text{max}}$) and direction $u$ (denoted $f_u^{\text{max}}$)? Let $f_m = \max(f_t^{\text{max}},f_u^{\text{max}})$. Explain why $f_m$ is the limit frequency (in sens of Shannon) for the sampling of $s_{45}$.

# %% [markdown]
# * <font color='red'> Pour déterminer les fréquences maximales, on calcule la TF de $s_\theta$ : </font>
# * <font color='red'> $\mathcal{S_\theta}(f, g) = \frac{A}{2} ( \delta(f-f_0\cos\theta) \delta(g-f_0\sin\theta) + \delta(f+f_0\cos\theta) \delta(g + f_0\sin\theta) )$. Ainsi on obtient : </font>
# * <font color='red'> $f_t^{\text{max}} = f_0\cos(\theta) = f_0(\sqrt2/2) $ &emsp; avec $\theta = 45 $ </font>
# * <font color='red'> $f_u^{\text{max}} = f_0\sin(\theta) = f_0(\sqrt2/2) $ &emsp; avec $\theta = 45 $ </font>
# * <font color='red'> Donc $f_m = f_0(\sqrt2/2)$ </font>
# * <font color='red'> $f_m$ définit la fréquence d'échantillonnage limite pour que le signal original puisse être reconstruit à partir des échantillons, dans le cas inverse où on sous-échantillonne (ie lorsque la fréquence d'échantillonnage est inférieure à deux fois la fréquence maximale) celà entraîne un repliement de spectres. </font>

# %% [markdown]
# 2. (a)  Sample $s_{45}$ with $f_e = 16 f_m$ and display the sampled signal.

# %%
T0 = 64
fm = ( 1 / T0 ) * ( np.sqrt(2) / 2 )
fe = 16 * fm
Te = 1 / fe
s2 = sinusoid2d(1, 45, 512, T0, Te)
imshow(s2)

# %% [markdown]
# 2. (b) Compute the Fourier transform of the sampled signal and display frequencies. One can use `surf()` function for an interactive 3D plot.

# %%
def computeFT(I):
    #Array -> Array[complex]
    return fft2(I)

def toVisualizeFT(If):
    #Array[complex] -> Array[float],
    return fftshift(abs(If))

def toVisualizeLogFT(If):
    #Array[complex] -> Array[float],
    return fftshift(np.log(1+abs(If)))

# %%
fft_s1 = computeFT(s1)
fft_s2 = computeFT(s2)

fs1 = toVisualizeFT(fft_s1)
#imshow(fs1)
surf(fs1)
fs2 = toVisualizeFT(fft_s2)
#imshow(fs2)

# %% [markdown]
# 3. (c) Comment the spectrum:
#     - verify the presence of the two Dirac peaks
#     - for various values of $T_e$, observe changes in the spectrum. Compare with the spectrum of the continuous signal ($s_{45}$). What is the origin of theses differences?
#     - (Bonus question):
#         - Why, aside the two Dirac peaks, there are somes structures? Explain the origin of these lobes.
#         - Increase $T_0$ in order to obtain a unique peak. Explain the origin of this fusion. Verify the limit value of $T_0$ for which the two peaks interfer.

# %%
# Pour faire varier Te
for i in range(20):
    T0 = 64
    fm = ( 1 / T0 ) * ( np.sqrt(2) / 2 )
    fe = 1 * ( i * 10 ) * fm
    Te = 1 / fe
    s = sinusoid2d(1, 45, 512, T0, Te) 
    imshow( toVisualizeFT( computeFT(s) ) )
# Out:
# C:\Users\wuwen\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars

# %%
# Pour faire varier T0
for i in np.arange(10,200,10):
    T0 = 1 * i * 10
    print("T0 : ",T0)
    fm = ( 1 / T0 ) * ( np.sqrt(2) / 2 )
    fe = 16 * fm
    Te = 1 / fe
    s = sinusoid2d(1, 45, 512, T0, Te)
    imshow( toVisualizeFT( computeFT(s) ) )
# Out:
# T0 :  100
# T0 :  200
# T0 :  300
# T0 :  400
# T0 :  500
# T0 :  600
# T0 :  700
# T0 :  800
# T0 :  900
# T0 :  1000
# T0 :  1100
# T0 :  1200
# T0 :  1300
# T0 :  1400
# T0 :  1500
# T0 :  1600
# T0 :  1700
# T0 :  1800
# T0 :  1900

# %% [markdown]
# * <font color='red'> On observe bien les deux pics de Dirac sur le module de la TF </font>
# * <font color='red'> Plus $f_e$ est grande et plus le nombre de pixels affichés augmente donc on observe de moins en moins les pics de Dirac sur le module de la TF, l'origine de ces différences est due à $f_e$ </font>
# * <font color='red'> Les structures à côté des pics de Dirac se trouvent être des lobes provenant du sinus cardinal. </font>
# * <font color='red'> En augmentant considérablement $T_0$ (>1000) on visualise un unique pic sur le module car la dimension de l'image se réduit au fur et à mesure que $T_0$ augmente. </font>

# %% [markdown]
# 4. (a) Sample $s_{45}$ with $f_0=4 f_m$ and display the sampled signal.

# %%
T0 = 64
fm = ( 1 / T0 ) * ( np.sqrt(2) / 2 )
f0 = 4 * fm
T0 = 1 / f0
s3 = sinusoid2d(1, 45, 512, T0, 1)
imshow(s3)

# %% [markdown]
# 4. (b) Write a function `error()` implementing the relative average error $\displaystyle\epsilon_r = \frac 1{2AL^2}\sum_{k=0}^L\sum_{l=0}^L |x_r(k,l)-x_d(k,l)|$.

# %%
def error(A, L, xr, xd):
    return ( 1 / (2 * A * L * L) ) * np.sum( np.abs( xr - xd ) )

# %% [markdown]
# 4. (c) Reconstruct the sampled signal. Display original and reconstruted signal.
#
# Print the orignal signal. Print the relative average error between the original and reconstructed images. What is the origin of this error?

# %%
# Signal reconstruit via l'interpolation de Shannon
xr_1 = shannonInterpolation(s1, 1, 512) 

# Calcul de l'erreur moyenne entre le signal original et celui reconstruit
eps = error(1, 512, xr_1,s1) 

imshow(s1, "Signal original")

imshow(xr_1, "Signal reconstruit")

print("Erreur moyenne : ", eps)
# Out:
# Erreur moyenne :  1.8965307571401425e-16

# %% [markdown]
# * <font color='red'> On observe que le signal reconstruit est identique au signal original, de plus la valeur de l'erreur moyenne est relativement très faible (d'ordre -16), celà s'explique par le fait que le signal est à support fréquentiel borné et qu'il a été correctement échantillonné en respectant les conditions du théorème de Shannon. </font>

# %% [markdown]
# 5. Same question than 4. with $f_e = \frac32f_m$. Comment the effects of aliasing.

# %%
# Echantillonnage 
fe = ( 3 / 2 ) * fm
Te = 1 / fe
s4 = sinusoid2d(1, 45, 512, 64, Te)

# Signal reconstruit
xr_4 = shannonInterpolation(s4, Te, s4.shape[0])

# Erreur moyenne
eps = error(1, 512, xr_4, s4)

imshow(s4, "Signal original")

imshow(xr_4, "Signal reconstruit")

print("Erreur moyenne : ", eps)
# Out:
# Erreur moyenne :  0.0001531099195674879

# %% [markdown]
# * <font color='red'> Ici l'image du signal reconstruit semble assez dégradée, de plus en comparant avec la précédente erreur, celle-ci est plus élevée (d'ordre -4). </font>
# * <font color='red'> L'aliasing entraîne la présence de fréquences qui ne devraient normalement pas s'y trouver d'où le fait que l'image reconstruit semble dégradée et celà est du au non respect du théorème de Shannon. </font>

# %% [markdown]
# 6. Consider the continuous signal with an oriention of $\theta=10°$. What is the value of $f_m$? With a sampling of $\frac32 f_e$ what is the additional drawback appearing after the reconstruction? Explain.

# %%
# Considération nouveau fm avec theta = 10 degrés
f_t = np.cos( ( np.pi / 180 ) * 10 ) * (1/64)
f_u = np.sin( ( np.pi / 180 ) * 10 ) * (1/64)
fm = max( f_t, f_u )

# Echantillonnage
fe = (3/2) * fm
Te = 1 / fe
s5 = sinusoid2d(1, 10, 512, 64, Te)

# Signal reconstruit
xr_5 = shannonInterpolation(s5, Te, s5.shape[0])

imshow(s5, "Image original")

imshow(xr_5, "Image reconstruite")

# Erreur moyenne
eps = error(1, 512, xr_5, s5)
print("Erreur moyenne : ", eps)
# Out:
# Erreur moyenne :  0.00027687810510826084

# %% [markdown]
# * <font color='red'> $f_t^{\text{max}} = f_0\cos(\theta) $ &emsp; avec $\theta = 10 $ </font>
# * <font color='red'> $f_u^{\text{max}} = f_0\sin(\theta) $ &emsp; avec $\theta = 10 $ </font>
# * <font color='red'> Donc $f_m = f_0\cos\theta$ </font>
# * <font color='red'> Sachant que $f_e$ < 2*$f_m$, on observe sur l'image reconstruite une perte d'information ainsi qu'une dégradation de l'image, celà provient du fait que le théorème de Shannon n'a pas été respecté et donc provoque l'effet d'aliasing. </font>

# %% [markdown]
# 7. Bonus question: write a function `shannonInterpolationLoop()` implementing equation (1) using two loops, in a C way. Compare and discuss the run time of this function and  `shannonInterpolation()` on a small signal ($L=64$). Run time way be measured using `tic()` and `tac()` functions.

# %% [markdown]
# $$
# x_r (t,u) = \sum_{k=-\infty}^{+\infty} \sum_{l=\infty}^{+\infty} x_e(kT_e,lT_e) \operatorname{sinc}(\pi f_e (t-kT_e)) \operatorname{sinc}(\pi f_e(u - lTe))\qquad\qquad\qquad\text{(1)}
# $$

# %%
from time import process_time
mytime = 0
def tic():
    """ NoneType -> NoneType """
    global mytime
    mytime = process_time()
def tac():
    """ NoneType -> int """
    global mytime
    print (process_time()-mytime)
    mytime = process_time()

### your code starts below
def shannonInterpolationLoop(I, Te, size) :
    
    xr = np.zeros(I.shape)
    
    for t in range(I.shape[0]) :
        for u in range(I.shape[1]) :
            xr[t,u] = I[t*Te][u*Te] * np.sinc(np.pi * (1/Te) * (t - t*Te)) * np.sinc(np.pi * (1/Te) * (u - u*Te))
            
    return xr

#imshow(shannonInterpolationLoop(s5,64,s5.shape[0]))
np.sinc(np.arange(0,12,1))
# Out:
# array([ 1.00000000e+00,  3.89817183e-17, -3.89817183e-17,  3.89817183e-17,
#        -3.89817183e-17,  3.89817183e-17, -3.89817183e-17,  3.89817183e-17,
#        -3.89817183e-17,  3.89817183e-17, -3.89817183e-17,  1.41787526e-16])

# %%
def sha(I, Te, Size):
    xr = np.zeros(I.shape)
    periodes = np.linspace(0, I.shape[0], Te)
    for t in range(I.shape[0]) :
        for u in range(I.shape[1]) :
            xr[t,u] = np.sum(I[periodes]  * np.sinc(np.pi * (1/Te) * (t - periodes)) * np.sinc(np.pi * (1/Te) * (u - periodes)))
    return xr

imshow(s5)
ss1 = sha(s5, 1, s5.shape[0])
imshow(ss1)
# Out:
# C:\Users\wuwen\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-01a97f4a31b8> in <module>()
#       9
#      10 imshow(s5)
# ---> 11 ss1 = sha(s5, Te, s5.shape[0])
#      12 imshow(ss1)
#
# <ipython-input-56-01a97f4a31b8> in sha(I, Te, Size)
#       1 def sha(I, Te, Size):
#       2     xr = np.zeros(I.shape)
# ----> 3     periodes = int(np.linspace(0, I.shape[0], Te))
#       4     print(periodes)
#       5     for t in range(I.shape[0]) :
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %% [markdown]
# ## Exercice 2: aliasing on natural images
#
# In this exercice, we study aliasing on image `img/barbara.png`. Aliasing occurring with subsample of image, we propose to write a code that implements a subsample (using function `subSample2()` of factor 2 on the image.

# %%
from PIL import Image

barbara = np.array(Image.open('img/barbara.png'))

def subSample2(I):
    """ Array -> Array """
    return I[::2,::2]

# %% [markdown]
# 1. Explain what is a subsample of factor 2 and the impact when applied on an image.

# %% [markdown]
# * <font color='red'> Le sous-échantillonnage permet de réduire la dimension d'une image et donc de se retrouver avec une image plus petite, un sous-échantillonnage de facteur 2 réduit donc la taille de l'image par 2.
# * <font color="red"> Un sous-échantillonnage a tendance à provoquer un aliasing proportionnel au facteur </font>

# %% [markdown]
# 2. Write a code that
#  - iterates the subsampling process
#  - computes the Fourier transform at each iteration, including the original image; and display frequencies
#
#    Describe and interpret the effects of aliasing. Why aliasing is a drawback ?

# %%
img = barbara

imshow(img,"Image originale")

for i in np.arange(3) :
    
    img_deg = subSample2(img)
    imshow(img_deg,"Image dégradée x "+str((i+1)*2))
    
    img = img_deg
# Out:
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# * <font color='red'> L'aliasing provoque un effet escalier sur l'image, plus particulièrement sur les contours où se situent les hautes fréquences. </font>
# * <font color='red'> L 'aliasing est un inconvénient car elle dégrade l'image </font>

# %% [markdown]
# 3. Bonus question: same question with the image `img/mandrill.png`.

# %%
mandrill = np.array(Image.open('img/mandrill.png'))
### your code and comments start below

imshow(mandrill,"Image originale")

for i in np.arange(5) :
    
    img_deg = subSample2(mandrill)
    imshow(img_deg,"Image dégradée x "+str((i+1)*2))
    
    mandrill = img_deg
# Out:
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# * <font color="red"> Même comportement pour l'image du mandrill, on remarque que l'aliasing se manisfeste dans un premier temps autour du visage, l'endroit où se situe les hautes fréquences </font>
